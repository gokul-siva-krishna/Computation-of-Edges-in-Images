# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import cv2
from PIL import Image 
from visibility_graph import visibility_graph

# %%
df = pd.read_excel(r'CatDogEdges.xlsx') #Master Dataframe
imgs=df['Images']
lis_edges=[]
direc=r'images' #folder where images exist
c=0
for i in imgs:
    path=direc+'\\'+i
    print(path)
    pic=cv2.imread(path, 0)
    img = Image.open(path)
    nu = asarray(img)
    flat=arr.flatten()
    #compute visual graphs lenght here
    e=visibility_graph(flat)
    l=e.edges()
    lis_edges.apped(len(l))
    #append all values to a list
#add list to the dataframe and save

# %%
from PIL import Image
from numpy import asarray 

n=10
img = Image.open('images\\0.jpg')
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray_img = cv2.resize(img, (10,10), interpolation = cv2.INTER_AREA)
img_final = cv2.GaussianBlur(gray_img,(3,3), sigmaX=0, sigmaY=0)
Gx = cv2.Sobel(img_final,cv2.CV_64F,1,0,ksize=5)  # x
Gy = cv2.Sobel(img_final,cv2.CV_64F,0,1,ksize=5)  # y
#arr = asarray(Gx)
#flat_=arr.flatten()
#print(flat_)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-12-621554fcab21> in <module>
#       5 img = Image.open('images\\0.jpg')
#       6 #gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# ----> 7 gray_img = cv2.resize(img, (10,10), interpolation = cv2.INTER_AREA)
#       8 img_final = cv2.GaussianBlur(gray_img,(3,3), sigmaX=0, sigmaY=0)
#       9 Gx = cv2.Sobel(img_final,cv2.CV_64F,1,0,ksize=5)  # x
#
# error: OpenCV(4.5.3) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'

# %%
pic=cv2.imread('images\\0.jpg')
img = Image.open('images\\0.jpg')
#plt.imshow(img)
n=277
img_ = cv2.resize(pic, (n,n))
gray_img = cv2.cvtColor(pic, cv2.COLOR_BGR2GRAY)
img_final = cv2.GaussianBlur(gray_img,(3,3), sigmaX=0, sigmaY=0)

plt.imshow(img_)

# %%
Gx = cv2.Sobel(img_final,cv2.CV_64F,1,0,ksize=5)  # x
Gy = cv2.Sobel(img_final,cv2.CV_64F,0,1,ksize=5)  # y
nu = asarray(Gx)
flat=nu.flatten()
#compute visual graphs lenght here
e=visibility_graph(flat)
l=e.edges()
print(len(l))
